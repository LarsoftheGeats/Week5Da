# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('supermarket.csv')

# %%
df
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 0           1        1659             1961                   530        66490
# 1           2        1461             1752                   210        39820
# 2           3        1340             1609                   720        54010
# 3           4        1451             1748                   620        53730
# 4           5        1770             2111                   450        46620
# ..        ...         ...              ...                   ...          ...
# 891       892        1582             1910                  1080        66390
# 892       893        1387             1663                   850        82080
# 893       894        1200             1436                  1060        76440
# 894       895        1299             1560                   770        96610
# 895       896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store_id              896 non-null    int64
#  1   store_area            896 non-null    int64
#  2   items_available       896 non-null    int64
#  3   daily_customer_count  896 non-null    int64
#  4   store_sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
#Sort Function
df.sort_values(by=['store_sales','store_area'], axis=0, ascending=False)
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 649       650        1989             2414                   860       116320
# 868       869        1775             2104                   980       105150
# 432       433        1365             1638                   680       102920
# 408       409        1303             1587                  1310       102310
# 758       759        1486             1758                   820       101820
# ..        ...         ...              ...                   ...          ...
# 352       353        1397             1686                   850        21300
# 593       594        1624             1946                   870        20270
# 775       776        1537             1877                   660        17670
# 852       853        1477             1790                   880        16370
# 31         32        1250             1508                   990        14920
#
# [896 rows x 5 columns]

# %%
pd.options.display.max_rows=530
df[df.store_area.duplicated(keep=False)].head(530)
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 0           1        1659             1961                   530        66490
# 1           2        1461             1752                   210        39820
# 2           3        1340             1609                   720        54010
# 3           4        1451             1748                   620        53730
# 4           5        1770             2111                   450        46620
# 5           6        1442             1733                   760        45260
# 6           7        1542             1858                  1030        72240
# 10         11        1187             1439                  1090        71280
# 11         12        1751             2098                   720        57620
# 13         14        1615             1931                  1160        59130
# 16         17        1578             1907                  1440        77250
# ...

# %%
df[df.store_area==1659]
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 0           1        1659             1961                   530        66490
# 313       314        1659             2008                   620        35120
# 733       734        1659             1999                   650        65660

# %%
df.sort_values(by=['store_area'], axis=0, ascending=False)
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales
# 466       467        2229             2667                   660        87410
# 540       541        2214             2647                   740        65900
# 91         92        2169             2617                   600        67080
# 849       850        2067             2492                   790        70230
# 398       399        2063             2493                   810        51480
# ..        ...         ...              ...                   ...          ...
# 72         73         891             1073                   630        67370
# 549       550         869             1050                   850        52540
# 744       745         854             1018                   660        77740
# 865       866         780              951                   790        25600
# 158       159         775              932                  1090        42530
#
# [896 rows x 5 columns]

# %%
df['sales_per_customer']=df['store_sales']/df['daily_customer_count']

# %%
df
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales  \
# 0           1        1659             1961                   530        66490
# 1           2        1461             1752                   210        39820
# 2           3        1340             1609                   720        54010
# 3           4        1451             1748                   620        53730
# 4           5        1770             2111                   450        46620
# ..        ...         ...              ...                   ...          ...
# 891       892        1582             1910                  1080        66390
# 892       893        1387             1663                   850        82080
# 893       894        1200             1436                  1060        76440
# 894       895        1299             1560                   770        96610
# 895       896        1174             1429                  1110        54340
#
#      sales_per_customer
# ...

# %%
len(df.store_area.unique())
# Out:
# 583

# %%
df_area_sales=df.groupby('store_area').sum('store_sales').reset_index()

# %%
df
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales  \
# 0           1        1659             1961                   530        66490
# 1           2        1461             1752                   210        39820
# 2           3        1340             1609                   720        54010
# 3           4        1451             1748                   620        53730
# 4           5        1770             2111                   450        46620
# ..        ...         ...              ...                   ...          ...
# 891       892        1582             1910                  1080        66390
# 892       893        1387             1663                   850        82080
# 893       894        1200             1436                  1060        76440
# 894       895        1299             1560                   770        96610
# 895       896        1174             1429                  1110        54340
#
#      sales_per_customer
# ...

# %%
df_area_sales=df_area_sales[['store_area','store_sales']]

# %%
df_area_sales.rename(columns={'store_sales':'area_sales'},inplace=True)

# %%
df.merge(df_area_sales, how='inner', on=['store_area'])
# Out:
#      store_id  store_area  items_available  daily_customer_count  store_sales  \
# 0           1        1659             1961                   530        66490
# 1         314        1659             2008                   620        35120
# 2         734        1659             1999                   650        65660
# 3           2        1461             1752                   210        39820
# 4         671        1461             1739                  1250        22310
# ..        ...         ...              ...                   ...          ...
# 891       881        1263             1516                   780        70980
# 892       883        1819             2187                   590        47920
# 893       884        1357             1625                  1140        52160
# 894       888        1156             1398                   140        92370
# 895       893        1387             1663                   850        82080
#
# ...

# %%
pd.options.display.max_rows=15
(i==df_area_sales.store_area)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 578    False
# 579    False
# 580    False
# 581    False
# 582    False
# Name: store_area, Length: 583, dtype: bool

# %%
df['area_sales'].iloc['store_area'==df_area_sales.store_area]=df_area_sales['store_sales'].iloc['store_area'=df.store_area]
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_18004\269878958.py", line 1
#     df['area_sales'].iloc['store_area'==df_area_sales.store_area]=df_area_sales['store_sales'].iloc['store_area'=df.store_area]
#                                                                                                                 ^
# SyntaxError: invalid syntax

# %%
df
(df.area_sales).isna().sum()
# Out:
# 891

# %%
df.area_sales.unique()
# Out:
# array([   nan, 42530., 25600., 77740., 52540., 67370.])

# %%
    df.area_sales[df['store_area']==1659]
# Out:
# 0     NaN
# 313   NaN
# 733   NaN
# Name: area_sales, dtype: float64
